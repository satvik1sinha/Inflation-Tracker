# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Global Dataset of Inflation.csv',encoding='ISO-8859-1')

# %%
data.head()
# Out:
#   Country Code  IMF Country Code               Country Indicator Type  \
# 0          ABW             314.0                 Aruba      Inflation
# 1          AFG             512.0           Afghanistan      Inflation
# 2          AGO             614.0                Angola      Inflation
# 3          ALB             914.0               Albania      Inflation
# 4          ARE             466.0  United Arab Emirates      Inflation
#
#                          Series Name   1970   1971   1972   1973   1974  ...  \
# 0  Headline Consumer Price Inflation    NaN    NaN    NaN    NaN    NaN  ...
# 1  Headline Consumer Price Inflation  25.51  25.51 -12.52 -10.68  10.23  ...
# 2  Headline Consumer Price Inflation   7.97   5.78  15.80  15.67  27.42  ...
# 3  Headline Consumer Price Inflation    NaN    NaN    NaN    NaN    NaN  ...
# 4  Headline Consumer Price Inflation  21.98  21.98  21.98  21.98  21.98  ...
#
#     2019   2020   2021   2022                      Note  Unnamed: 59  \
# ...

# %%
data.describe()
# Out:
#        IMF Country Code        1970        1971        1972        1973  \
# count        781.000000  422.000000  428.000000  430.000000  430.000000
# mean         536.507042    5.867854    6.057173    7.705721   14.538465
# std          271.783250    7.283523    8.617909   11.701059   28.889492
# min          111.000000  -26.098150  -19.700000  -12.520000  -13.240000
# 25%          283.000000    1.640000    1.900000    3.015000    6.000000
# 50%          546.000000    4.360000    4.695000    5.590000    9.930000
# 75%          732.000000    7.670000    7.625000    8.775000   15.900000
# max          968.000000   61.000000   94.500000  115.200000  376.500000
#
#              1974        1975        1976        1977        1978  ...  \
# count  434.000000  434.000000  430.000000  427.000000  428.000000  ...
# mean    24.174101   16.539424   15.472047   15.123021   12.062360  ...
# std     39.117175   28.749170   37.833455   27.881710   18.019203  ...
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of     Country Code  IMF Country Code               Country Indicator Type  \
# 0            ABW             314.0                 Aruba      Inflation
# 1            AFG             512.0           Afghanistan      Inflation
# 2            AGO             614.0                Angola      Inflation
# 3            ALB             914.0               Albania      Inflation
# 4            ARE             466.0  United Arab Emirates      Inflation
# ..           ...               ...                   ...            ...
# 778          VEN             299.0         Venezuela, RB      Inflation
# 779          VNM             582.0               Vietnam      Inflation
# 780          XKX             967.0                Kosovo      Inflation
# 781          ZAF             199.0          South Africa      Inflation
# 782          ZMB             754.0                Zambia      Inflation
#
# ...

# %%
data=data.drop(columns=['Note', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63'], errors='ignore')

# %%
data.head()
# Out:
#   Country Code  IMF Country Code               Country Indicator Type  \
# 0          ABW             314.0                 Aruba      Inflation
# 1          AFG             512.0           Afghanistan      Inflation
# 2          AGO             614.0                Angola      Inflation
# 3          ALB             914.0               Albania      Inflation
# 4          ARE             466.0  United Arab Emirates      Inflation
#
#                          Series Name   1970   1971   1972   1973   1974  ...  \
# 0  Headline Consumer Price Inflation    NaN    NaN    NaN    NaN    NaN  ...
# 1  Headline Consumer Price Inflation  25.51  25.51 -12.52 -10.68  10.23  ...
# 2  Headline Consumer Price Inflation   7.97   5.78  15.80  15.67  27.42  ...
# 3  Headline Consumer Price Inflation    NaN    NaN    NaN    NaN    NaN  ...
# 4  Headline Consumer Price Inflation  21.98  21.98  21.98  21.98  21.98  ...
#
#    2013  2014  2015   2016   2017   2018   2019   2020   2021   2022
# ...

# %%
data = data[data['Series Name'] == 'Headline Consumer Price Inflation']

# %%
data.tail()
# Out:
#     Country Code  IMF Country Code                   Country Indicator Type  \
# 198          NCL             687.0             New Caledonia      Inflation
# 199          NIU             570.0                      Niue      Inflation
# 200          SHN             654.0              Saint Helena      Inflation
# 201          TLS             537.0               Timor-Leste      Inflation
# 202          TCA             796.0  Turks and Caicos Islands      Inflation
#
#                            Series Name  1970  1971  1972  1973  1974  ...  \
# 198  Headline Consumer Price Inflation   NaN   NaN   NaN   NaN   NaN  ...
# 199  Headline Consumer Price Inflation   NaN   NaN   NaN   NaN   NaN  ...
# 200  Headline Consumer Price Inflation   NaN   NaN   NaN   NaN   NaN  ...
# 201  Headline Consumer Price Inflation   NaN   NaN   NaN   NaN   NaN  ...
# 202  Headline Consumer Price Inflation   NaN   NaN   NaN   NaN   NaN  ...
#
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of     Country Code  IMF Country Code                   Country Indicator Type  \
# 0            ABW             314.0                     Aruba      Inflation
# 1            AFG             512.0               Afghanistan      Inflation
# 2            AGO             614.0                    Angola      Inflation
# 3            ALB             914.0                   Albania      Inflation
# 4            ARE             466.0      United Arab Emirates      Inflation
# ..           ...               ...                       ...            ...
# 198          NCL             687.0             New Caledonia      Inflation
# 199          NIU             570.0                      Niue      Inflation
# 200          SHN             654.0              Saint Helena      Inflation
# 201          TLS             537.0               Timor-Leste      Inflation
# 202          TCA             796.0  Turks and Caicos Islands      Inflation
#
# ...

# %%
data = data.drop(columns=['IMF Country Code','Series Name'])
data.head()
# Out:
#   Country Code               Country Indicator Type   1970   1971   1972  \
# 0          ABW                 Aruba      Inflation    NaN    NaN    NaN
# 1          AFG           Afghanistan      Inflation  25.51  25.51 -12.52
# 2          AGO                Angola      Inflation   7.97   5.78  15.80
# 3          ALB               Albania      Inflation    NaN    NaN    NaN
# 4          ARE  United Arab Emirates      Inflation  21.98  21.98  21.98
#
#     1973   1974   1975   1976  ...  2013  2014  2015   2016   2017   2018  \
# 0    NaN    NaN    NaN    NaN  ... -2.37  0.42  0.48  -0.89  -0.47   3.58
# 1 -10.68  10.23  11.85   0.60  ...  7.39  4.67 -0.66   4.38   4.98   0.63
# 2  15.67  27.42  29.00  80.70  ...  8.78  7.30  9.16  32.38  29.84  19.63
# 3    NaN    NaN    NaN    NaN  ...  1.93  1.62  1.91   1.29   1.99   2.03
# 4  21.98  21.98  21.98  21.98  ...  1.09  2.34  4.07   1.62   1.97   3.06
#
#     2019   2020   2021   2022
# 0   4.26   1.22   0.74   6.04
# ...

# %%
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Country Code       0
# Country            0
# Indicator Type     0
# 1970              48
# 1971              48
# 1972              48
# 1973              47
# 1974              47
# 1975              49
# 1976              49
# 1977              49
# 1978              48
# 1979              48
# 1980              45
# 1981              41
# 1982              40
# 1983              40
# 1984              40
# 1985              40
# 1986              39
# 1987              38
# 1988              38
# 1989              38
# 1990              37
# 1991              34
# 1992              28
# 1993              24
# 1994              23
# 1995              22
# 1996              19
# 1997              18
# 1998              17
# 1999              16
# 2000              15
# 2001              12
# 2002              12
# 2003               9
# 2004               8
# 2005               5
# 2006               5
# 2007               5
# 2008               5
# 2009               5
# ...

# %%
# Replace NaN values with the mean inflation rate for each country
data_filled = data.copy()

# Calculate the mean for each country across the inflation columns (ignoring NaN)
data_filled.iloc[:, 3:] = data.iloc[:, 3:].apply(lambda row: row.fillna(row.mean()), axis=1)

# Check the result
data_filled.head()
# Out:
#   Country Code               Country Indicator Type       1970       1971  \
# 0          ABW                 Aruba      Inflation   2.447037   2.447037
# 1          AFG           Afghanistan      Inflation  25.510000  25.510000
# 2          AGO                Angola      Inflation   7.970000   5.780000
# 3          ALB               Albania      Inflation  15.221212  15.221212
# 4          ARE  United Arab Emirates      Inflation  21.980000  21.980000
#
#         1972       1973       1974       1975       1976  ...  2013  2014  \
# 0   2.447037   2.447037   2.447037   2.447037   2.447037  ... -2.37  0.42
# 1 -12.520000 -10.680000  10.230000  11.850000   0.600000  ...  7.39  4.67
# 2  15.800000  15.670000  27.420000  29.000000  80.700000  ...  8.78  7.30
# 3  15.221212  15.221212  15.221212  15.221212  15.221212  ...  1.93  1.62
# 4  21.980000  21.980000  21.980000  21.980000  21.980000  ...  1.09  2.34
#
#    2015   2016   2017   2018   2019   2020   2021       2022
# ...

# %%
data = data_filled.copy()

# %%
data.head()
# Out:
#   Country Code               Country Indicator Type       1970       1971  \
# 0          ABW                 Aruba      Inflation   2.447037   2.447037
# 1          AFG           Afghanistan      Inflation  25.510000  25.510000
# 2          AGO                Angola      Inflation   7.970000   5.780000
# 3          ALB               Albania      Inflation  15.221212  15.221212
# 4          ARE  United Arab Emirates      Inflation  21.980000  21.980000
#
#         1972       1973       1974       1975       1976  ...  2013  2014  \
# 0   2.447037   2.447037   2.447037   2.447037   2.447037  ... -2.37  0.42
# 1 -12.520000 -10.680000  10.230000  11.850000   0.600000  ...  7.39  4.67
# 2  15.800000  15.670000  27.420000  29.000000  80.700000  ...  8.78  7.30
# 3  15.221212  15.221212  15.221212  15.221212  15.221212  ...  1.93  1.62
# 4  21.980000  21.980000  21.980000  21.980000  21.980000  ...  1.09  2.34
#
#    2015   2016   2017   2018   2019   2020   2021       2022
# ...

# %%
# List of top 10 economies by country name
top_10_economies = ['United States', 'China', 'Japan', 'Germany', 'India', 
                    'United Kingdom', 'France', 'Brazil', 'Italy', 'Canada']

# Filter the dataset based on these countries
top_10_economies_data = data[data['Country'].isin(top_10_economies)]

# Display the head of the new dataset
top_10_economies_data.head(10)
# Out:
#     Country Code         Country Indicator Type   1970   1971   1972   1973  \
# 23           BRA          Brazil      Inflation  22.26  20.14  16.52  12.65
# 30           CAN          Canada      Inflation   3.37   2.70   4.99   7.49
# 33           CHN           China      Inflation   1.06   1.05   1.04   1.03
# 45           DEU         Germany      Inflation   3.45   5.24   5.48   7.03
# 59           FRA          France      Inflation   5.85   5.40   6.06   7.38
# 62           GBR  United Kingdom      Inflation   6.37   9.44   7.07   9.20
# 79           IND           India      Inflation   5.10   3.08   6.44  16.94
# 85           ITA           Italy      Inflation   4.81   4.79   5.75  10.80
# 88           JPN           Japan      Inflation   7.67   6.40   4.84  11.61
# 182          USA   United States      Inflation   5.90   4.29   3.27   6.18
#
#       1974   1975   1976  ...   2013  2014  2015  2016  2017  2018  2019  \
# ...

# %%
data.head()
# Out:
#   Country Code               Country Indicator Type       1970       1971  \
# 0          ABW                 Aruba      Inflation   2.447037   2.447037
# 1          AFG           Afghanistan      Inflation  25.510000  25.510000
# 2          AGO                Angola      Inflation   7.970000   5.780000
# 3          ALB               Albania      Inflation  15.221212  15.221212
# 4          ARE  United Arab Emirates      Inflation  21.980000  21.980000
#
#         1972       1973       1974       1975       1976  ...  2013  2014  \
# 0   2.447037   2.447037   2.447037   2.447037   2.447037  ... -2.37  0.42
# 1 -12.520000 -10.680000  10.230000  11.850000   0.600000  ...  7.39  4.67
# 2  15.800000  15.670000  27.420000  29.000000  80.700000  ...  8.78  7.30
# 3  15.221212  15.221212  15.221212  15.221212  15.221212  ...  1.93  1.62
# 4  21.980000  21.980000  21.980000  21.980000  21.980000  ...  1.09  2.34
#
#    2015   2016   2017   2018   2019   2020   2021       2022
# ...

# %%
data.shape
# Out:
# (203, 56)

# %%
data.dtypes
# Out:
# Country Code       object
# Country            object
# Indicator Type     object
# 1970              float64
# 1971              float64
# 1972              float64
# 1973              float64
# 1974              float64
# 1975              float64
# 1976              float64
# 1977              float64
# 1978              float64
# 1979              float64
# 1980              float64
# 1981              float64
# 1982              float64
# 1983              float64
# 1984              float64
# 1985              float64
# 1986              float64
# 1987              float64
# 1988              float64
# 1989              float64
# 1990              float64
# 1991              float64
# 1992              float64
# 1993              float64
# 1994              float64
# 1995              float64
# 1996              float64
# 1997              float64
# 1998              float64
# 1999              float64
# 2000              float64
# 2001              float64
# ...

# %%
data.isnull().sum()
# Out:
# Country Code      0
# Country           0
# Indicator Type    0
# 1970              2
# 1971              2
# 1972              2
# 1973              2
# 1974              2
# 1975              2
# 1976              2
# 1977              2
# 1978              2
# 1979              2
# 1980              2
# 1981              2
# 1982              2
# 1983              2
# 1984              2
# 1985              2
# 1986              2
# 1987              2
# 1988              2
# 1989              2
# 1990              2
# 1991              2
# 1992              2
# 1993              2
# 1994              2
# 1995              2
# 1996              2
# 1997              2
# 1998              2
# 1999              2
# 2000              2
# 2001              2
# 2002              2
# 2003              2
# 2004              2
# 2005              2
# 2006              2
# 2007              2
# 2008              2
# 2009              2
# 2010              2
# 2011              2
# ...

# %%
import matplotlib.pyplot as plt

# %%
#Distribution of Inflation Rates
inflation_columns = data.columns[3:]  # Assuming first three columns are Country Code, Country, Indicator Type
plt.figure(figsize=(12, 8))
data[inflation_columns].T.boxplot()
plt.xticks(rotation=90)
plt.title('Boxplot of Inflation Rates Over the Years')
plt.ylabel('Inflation Rate')
plt.xlabel('Year')
plt.show()

# %%
import seaborn as sns

# %%
#Correlation Analysis
correlation = data[inflation_columns].corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title('Correlation Heatmap of Inflation Rates')
plt.show()

# %%
#Yearly Analysis for India
country_data = data[data['Country'] == 'India'].iloc[:, 3:].T
country_data.columns = ['Inflation Rate']
plt.figure(figsize=(12, 6))
plt.plot(country_data.index, country_data['Inflation Rate'], marker='o')
plt.title('Inflation Rate Over the Years for India')
plt.xlabel('Year')
plt.ylabel('Inflation Rate')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
# Calculate Year-over-Year (YoY) percentage changes
yoy_changes = data.iloc[:, 3:].pct_change(axis=1) * 100

# Assign these changes back to the dataframe
data_yoy = data.copy()
data_yoy.iloc[:, 3:] = yoy_changes

# Display the head of the new dataset with YoY changes
data_yoy.head()
# Out:
#   Country Code               Country Indicator Type  1970       1971  \
# 0          ABW                 Aruba      Inflation   NaN   0.000000
# 1          AFG           Afghanistan      Inflation   NaN   0.000000
# 2          AGO                Angola      Inflation   NaN -27.478043
# 3          ALB               Albania      Inflation   NaN   0.000000
# 4          ARE  United Arab Emirates      Inflation   NaN   0.000000
#
#          1972       1973        1974       1975        1976  ...        2013  \
# 0    0.000000   0.000000    0.000000   0.000000    0.000000  ... -476.190476
# 1 -149.078793 -14.696486 -195.786517  15.835777  -94.936709  ...   14.751553
# 2  173.356401  -0.822785   74.984046   5.762217  178.275862  ...  -14.591440
# 3    0.000000   0.000000    0.000000   0.000000    0.000000  ...   -4.926108
# 4    0.000000   0.000000    0.000000   0.000000    0.000000  ...   65.151515
#
#          2014        2015        2016       2017        2018        2019  \
# ...

# %%
# Calculate 5-year moving averages for each row, ignoring non-numeric columns
moving_avg_5yr = data.iloc[:, 3:].rolling(window=5, axis=1).mean()

# Assign these averages back to the dataframe
data_ma = data.copy()
data_ma.iloc[:, 3:] = moving_avg_5yr

# Display the head of the new dataset with 5-year moving averages
data_ma.head()
# Out:
#   Country Code               Country Indicator Type  1970  1971  1972  1973  \
# 0          ABW                 Aruba      Inflation   NaN   NaN   NaN   NaN
# 1          AFG           Afghanistan      Inflation   NaN   NaN   NaN   NaN
# 2          AGO                Angola      Inflation   NaN   NaN   NaN   NaN
# 3          ALB               Albania      Inflation   NaN   NaN   NaN   NaN
# 4          ARE  United Arab Emirates      Inflation   NaN   NaN   NaN   NaN
#
#         1974       1975       1976  ...    2013    2014   2015    2016  \
# 0   2.447037   2.447037   2.447037  ...   0.504   1.016  0.696  -0.346
# 1   7.610000   4.878000  -0.104000  ...   4.200   6.496  5.928   4.444
# 2  14.528000  18.734000  33.718000  ...  12.148  10.864  9.800  13.580
# 3  15.221212  15.221212  15.221212  ...   2.646   2.512  2.180   1.756
# 4  21.980000  21.980000  21.980000  ...   1.016   1.170  1.808   1.956
#
#      2017    2018    2019    2020    2021       2022
# ...

# %%
# Combine original data with YoY changes and moving averages
data_combined = data.copy()

# Add '_yoy' and '_ma' suffixes to differentiate columns
data_combined.iloc[:, 3:] = data.iloc[:, 3:]
data_combined_yoy = yoy_changes.add_suffix('_yoy')
data_combined_ma = moving_avg_5yr.add_suffix('_ma')

# Concatenate original, YoY, and moving average data
data_combined = pd.concat([data, data_combined_yoy, data_combined_ma], axis=1)

# Display the combined dataset head
data_combined.head()
# Out:
#   Country Code               Country Indicator Type       1970       1971  \
# 0          ABW                 Aruba      Inflation   2.447037   2.447037
# 1          AFG           Afghanistan      Inflation  25.510000  25.510000
# 2          AGO                Angola      Inflation   7.970000   5.780000
# 3          ALB               Albania      Inflation  15.221212  15.221212
# 4          ARE  United Arab Emirates      Inflation  21.980000  21.980000
#
#         1972       1973       1974       1975       1976  ...  2013_ma  \
# 0   2.447037   2.447037   2.447037   2.447037   2.447037  ...    0.504
# 1 -12.520000 -10.680000  10.230000  11.850000   0.600000  ...    4.200
# 2  15.800000  15.670000  27.420000  29.000000  80.700000  ...   12.148
# 3  15.221212  15.221212  15.221212  15.221212  15.221212  ...    2.646
# 4  21.980000  21.980000  21.980000  21.980000  21.980000  ...    1.016
#
#    2014_ma  2015_ma  2016_ma  2017_ma  2018_ma  2019_ma  2020_ma  2021_ma  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation matrix
corr_matrix = data_combined.corr()

# Plot the heatmap
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()
# Out:
# C:\Users\Satvik Sinha\AppData\Local\Temp\ipykernel_55984\2658077599.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data_combined.corr()
# C:\Users\Satvik Sinha\anaconda3\lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
import numpy as np

# Plot histograms for YoY changes and 5-year moving averages
data_combined_yoy.hist(figsize=(15, 10), bins=20)
plt.show()

data_combined_ma.hist(figsize=(15, 10), bins=20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [30], in <cell line: 4>()
#       1 import numpy as np
#       3 # Plot histograms for YoY changes and 5-year moving averages
# ----> 4 data_combined_yoy.hist(figsize=(15, 10), bins=20)
#       5 plt.show()
#       7 data_combined_ma.hist(figsize=(15, 10), bins=20)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:231, in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     140 """
#     141 Make a histogram of the DataFrame's columns.
#     142
#    (...)
#     228     >>> hist = df.hist(bins=3)
#     229 """
#     230 plot_backend = _get_plot_backend(backend)
# --> 231 return plot_backend.hist_frame(
#     232     data,
#     233     column=column,
#     234     by=by,
#     235     grid=grid,
# ...

# %%
countries_to_plot = ['USA', 'IND', 'CHN']  # example countries

for country in countries_to_plot:
    country_data = data_combined[data_combined['Country Code'] == country].iloc[:, 3:]
    country_data.T.plot(figsize=(10, 6), title=f"Inflation Trends - {country}")
    plt.show()

# %%
data.head()
# Out:
#   Country Code               Country Indicator Type       1970       1971  \
# 0          ABW                 Aruba      Inflation   2.447037   2.447037
# 1          AFG           Afghanistan      Inflation  25.510000  25.510000
# 2          AGO                Angola      Inflation   7.970000   5.780000
# 3          ALB               Albania      Inflation  15.221212  15.221212
# 4          ARE  United Arab Emirates      Inflation  21.980000  21.980000
#
#         1972       1973       1974       1975       1976  ...  2013  2014  \
# 0   2.447037   2.447037   2.447037   2.447037   2.447037  ... -2.37  0.42
# 1 -12.520000 -10.680000  10.230000  11.850000   0.600000  ...  7.39  4.67
# 2  15.800000  15.670000  27.420000  29.000000  80.700000  ...  8.78  7.30
# 3  15.221212  15.221212  15.221212  15.221212  15.221212  ...  1.93  1.62
# 4  21.980000  21.980000  21.980000  21.980000  21.980000  ...  1.09  2.34
#
#    2015   2016   2017   2018   2019   2020   2021       2022
# ...

# %%
# Select the relevant columns for a single country
ind_data = data[data['Country'] == 'India'].iloc[:, 3:].T

# Rename the column for clarity
ind_data.columns = ['Inflation Rate']

# Reset the index to ensure the years are the index
ind_data.index = ind_data.index.astype(int)
ind_data = ind_data.sort_index()

# Preview the inflation time series
ind_data.head()
# Out:
#       Inflation Rate
# 1970            5.10
# 1971            3.08
# 1972            6.44
# 1973           16.94
# 1974           28.60

# %%
from statsmodels.tsa.stattools import adfuller

# Perform ADF test
adf_test = adfuller(ind_data['Inflation Rate'])

print(f"ADF Statistic: {adf_test[0]}")
print(f"p-value: {adf_test[1]}")
# Out:
# ADF Statistic: -4.632274498296203
# p-value: 0.0001125867197893644

# %%
#p value< 0.05, hence the series is stationary

# %%
from pmdarima import auto_arima

# Automatically select the best p, d, q for ARIMA
auto_arima_model = auto_arima(ind_data, seasonal=False, stepwise=True, trace=True)

# Check the best parameters
auto_arima_model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.43 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=385.776, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=332.124, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=350.116, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=333.979, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=327.174, Time=0.08 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=334.433, Time=0.11 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.21 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=344.027, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=312.139, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=310.745, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=319.365, Time=0.02 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=311.818, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=315.942, Time=0.01 sec
# ...

# %%
from statsmodels.tsa.arima.model import ARIMA

# Fit the ARIMA model
model = ARIMA(ind_data, order=(2,1,1))  # Replace p, d, q with values from auto_arima
model_fit = model.fit()

# Forecast for the next 5 years
forecast = model_fit.forecast(steps=5)
print(forecast)
# Out:
# 53    7.830706
# 54    7.748697
# 55    7.367115
# 56    7.235876
# 57    7.298543
# Name: predicted_mean, dtype: float64
# C:\Users\Satvik Sinha\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Satvik Sinha\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Satvik Sinha\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Satvik Sinha\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the number of years to forecast
forecast_horizon = len(forecast)  # Number of years in the forecast (e.g., 5)

# Define the last available year in the historical data (e.g., 2022)
last_year = 2022

# Create an array of years for the historical data (based on the years in your dataset)
historical_years = np.arange(last_year - len(ind_data) + 1, last_year + 1)

# Create an array of future years for the forecasted data (2023, 2024, ..., etc.)
forecast_years = np.arange(last_year + 1, last_year + 1 + forecast_horizon)

# Create the figure
plt.figure(figsize=(12, 6))

# Plot the historical inflation data (last N years)
plt.plot(historical_years, ind_data[-len(historical_years):], label='Historical Inflation', color='blue', linewidth=2)

# Plot the forecasted inflation data
plt.plot(forecast_years, forecast, label='Forecasted Inflation', color='red', linestyle='--', linewidth=2)

# Highlight the forecast period with a shaded area
plt.axvspan(last_year, last_year + forecast_horizon, color='gray', alpha=0.1, label='Forecast Period')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Inflation Rate')
plt.title('ARIMA Inflation Forecast with Historical Data')

# Add a vertical line to separate historical data from the forecast
plt.axvline(x=last_year, color='black', linestyle=':', label='Forecast Start')

# Add a legend and grid for clarity
plt.legend()
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Ensure ind_data is a single column (if it was a DataFrame with multiple columns)
if isinstance(ind_data, pd.DataFrame):
    ind_data = ind_data.iloc[:, 0]  # Select the first column

# %%
# Convert forecast to a DataFrame for easy access
forecast_df = pd.DataFrame({
    "Year": forecast_years,
    "Inflation Rate": forecast
})
# Define a function for user interaction
def get_inflation_rate():
    print("Welcome to the Inflation Tracker!")
    print(f"Available forecast years: {forecast_years[0]} to {forecast_years[-1]}")

    try:
        # Take year input
        year = int(input("Enter the year you want the inflation rate for: "))
        
        # Check if the year is in the forecast range
        if year in forecast_years:
            inflation_rate = forecast_df.loc[forecast_df["Year"] == year, "Inflation Rate"].values[0]
            print(f"The forecasted inflation rate for {year} is: {inflation_rate:.2f}%")
        else:
            print("Sorry, the year is out of the forecast range.")
            print(f"Please choose a year between {forecast_years[0]} and {forecast_years[-1]}.")
    
    except ValueError:
        print("Invalid input. Please enter a valid year.")

# Call the function to start interaction
get_inflation_rate()
# Out:
# Welcome to the Inflation Tracker!
# Available forecast years: 2023 to 2027
# Enter the year you want the inflation rate for: 2025
# The forecasted inflation rate for 2025 is: 7.70%

# %%
# Extend the forecast to 2040
forecast_years = list(range(2023, 2041))  # Include years from 2023 to 2040

# Forecast for the extended range
forecast = model_fit.forecast(steps=len(forecast_years))

# Convert forecast to a DataFrame for easy access
forecast_df = pd.DataFrame({
    "Year": forecast_years,
    "Inflation Rate": forecast
})

# Updated function for user interaction
def get_inflation_rate():
    print("Welcome to the Inflation Tracker!")
    print(f"Available forecast years: {forecast_years[0]} to {forecast_years[-1]}")

    try:
        # Take year input
        year = int(input("Enter the year you want the inflation rate for: "))
        
        # Check if the year is in the forecast range
        if year in forecast_years:
            inflation_rate = forecast_df.loc[forecast_df["Year"] == year, "Inflation Rate"].values[0]
            print(f"The forecasted inflation rate for {year} is: {inflation_rate:.2f}%")
        else:
            print("Sorry, the year is out of the forecast range.")
            print(f"Please choose a year between {forecast_years[0]} and {forecast_years[-1]}.")
    
    except ValueError:
        print("Invalid input. Please enter a valid year.")

# Call the function to start interaction
get_inflation_rate()
# Out:
# C:\Users\Satvik Sinha\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Welcome to the Inflation Tracker!
# Available forecast years: 2023 to 2040
# Enter the year you want the inflation rate for: 2037
# The forecasted inflation rate for 2037 is: 7.70%

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the number of years to forecast and the last available year in the historical data
forecast_horizon = len(forecast)  # Number of forecasted years (e.g., 5)
last_year = ind_data.index[-1]  # Use the last index year of ind_data

# Generate years for historical data and forecast data
historical_years = np.arange(last_year - len(ind_data) + 1, last_year + 1)
forecast_years = np.arange(last_year + 1, last_year + 1 + forecast_horizon)

# Plot historical and forecasted data
plt.figure(figsize=(12, 6))

# Plot historical data
plt.plot(historical_years, ind_data.values, label='Historical Inflation', color='blue', linewidth=2)

# Plot forecasted data
plt.plot(forecast_years, forecast, label='Forecasted Inflation', color='red', linestyle='--', linewidth=2)

# Add labels and other plot details
plt.xlabel('Year')
plt.ylabel('Inflation Rate')
plt.title('ARIMA Forecast for Inflation')
plt.axvline(x=last_year, color='black', linestyle=':', label='Forecast Start')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
from pmdarima import auto_arima

# Automatically determine the best p, d, q
auto_arima_model = auto_arima(
    ind_data, 
    seasonal=False, 
    stepwise=True, 
    suppress_warnings=True, 
    trace=True
)

# Print the best parameters
print(auto_arima_model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.78 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=385.776, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=332.124, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=350.116, Time=0.16 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=333.979, Time=0.14 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=327.174, Time=0.38 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=334.433, Time=0.78 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.83 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=344.027, Time=0.10 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=312.139, Time=0.18 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=310.745, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=319.365, Time=0.02 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=311.818, Time=0.17 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=315.942, Time=0.08 sec
# ...

# %%
from statsmodels.tsa.arima.model import ARIMA

# Use the optimal (p, d, q) from auto_arima
model = ARIMA(ind_data, order=auto_arima_model.order)
model_fit = model.fit()

# Forecast up to 2040
forecast_years = list(range(2023, 2041))
forecast = model_fit.forecast(steps=len(forecast_years))

# Convert forecast to DataFrame
forecast_df = pd.DataFrame({
    "Year": forecast_years,
    "Inflation Rate": forecast
})

print(forecast_df)
# Out:
#     Year  Inflation Rate
# 53  2023        7.987724
# 54  2024        7.696489
# 55  2025        7.696489
# 56  2026        7.696489
# 57  2027        7.696489
# 58  2028        7.696489
# 59  2029        7.696489
# 60  2030        7.696489
# 61  2031        7.696489
# 62  2032        7.696489
# 63  2033        7.696489
# 64  2034        7.696489
# 65  2035        7.696489
# 66  2036        7.696489
# 67  2037        7.696489
# 68  2038        7.696489
# 69  2039        7.696489
# 70  2040        7.696489
# C:\Users\Satvik Sinha\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Satvik Sinha\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
import matplotlib.pyplot as plt

# Plot historical data
plt.figure(figsize=(12, 6))
plt.plot(ind_data.index, ind_data.values, label="Historical Inflation", color="blue")

# Plot forecasted data
plt.plot(forecast_years, forecast, label="Forecasted Inflation", color="red", linestyle="--")

plt.title("Inflation Forecast (2023-2040)")
plt.xlabel("Year")
plt.ylabel("Inflation Rate (%)")
plt.legend()
plt.grid()
plt.show()

# %%
from prophet import Prophet
import pandas as pd

# Prepare data for Prophet
df_prophet = pd.DataFrame({
    'ds': pd.date_range(start='2000', periods=len(ind_data), freq='Y'),  # Replace with actual historical years
    'y': ind_data.values
})

# %%
# Initialize and fit the model
model = Prophet()
model.fit(df_prophet)
# Out:
# 00:05:12 - cmdstanpy - INFO - Chain [1] start processing
# 00:05:13 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Create a DataFrame for future years
future_years_1 = model.make_future_dataframe(periods=18, freq='Y')  # Forecast from 2023 to 2040
forecast_1 = model.predict(future_years_1)

# %%
# Plot the forecast
fig = model.plot(forecast_1)
plt.title("Inflation Forecast (2023-2040)")
plt.xlabel("Year")
plt.ylabel("Inflation Rate (%)")
plt.grid()
plt.show()

# %%
# Extract forecasted values
forecast_1_filtered = forecast_1[['ds', 'yhat']].tail(18)  # Get the forecast for the last 18 rows
forecast_1_filtered.columns = ['Year', 'Inflation Rate']
forecast_1_filtered['Year'] = forecast_1_filtered['Year'].dt.year  # Convert to year format

print(forecast_1_filtered)
# Out:
#     Year  Inflation Rate
# 53  2053        6.246449
# 54  2054        5.820985
# 55  2055        5.638856
# 56  2056        6.692424
# 57  2057        6.024079
# 58  2058        5.598616
# 59  2059        5.416487
# 60  2060        6.470054
# 61  2061        5.801710
# 62  2062        5.376246
# 63  2063        5.194118
# 64  2064        6.247685
# 65  2065        5.579341
# 66  2066        5.153877
# 67  2067        4.971748
# 68  2068        6.025316
# 69  2069        5.356971
# 70  2070        4.931508

# %%
# Create a mapping of year to forecasted inflation
forecast_dict = forecast_1[['ds', 'yhat']].set_index(forecast_1['ds'].dt.year)['yhat'].to_dict()

# %%
# Function to get inflation rate for a specific year
def get_inflation_rate(year):
    if year in forecast_dict:
        return f"The forecasted inflation rate for {year} is {forecast_dict[year]:.2f}%."
    else:
        return f"Year {year} is not within the forecast range (2023–2040)."

# User interaction
try:
    user_year = int(input("Enter a year between 2023 and 2040 to get the forecasted inflation rate: "))
    print(get_inflation_rate(user_year))
except ValueError:
    print("Please enter a valid year (numeric).")
# Out:
# Enter a year between 2023 and 2040 to get the forecasted inflation rate: 2038
# The forecasted inflation rate for 2038 is 6.71%.

# %%
# User interaction
try:
    user_year = int(input("Enter a year between 2023 and 2040 to get the forecasted inflation rate: "))
    print(get_inflation_rate(user_year))
except ValueError:
    print("Please enter a valid year (numeric).")
# Out:
# Enter a year between 2023 and 2040 to get the forecasted inflation rate: 2040
# The forecasted inflation rate for 2040 is 7.58%.
